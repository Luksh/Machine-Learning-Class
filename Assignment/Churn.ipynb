# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/LENOVO/Machine Learning/Assignment/churn.csv")
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter",x="Day Calls",y="Day Charge")
# Out:
# <Axes: xlabel='Day Calls', ylabel='Day Charge'>

# %%
df.plot(x="Day Calls",y="Night Calls")
# Out:
# <Axes: xlabel='Day Calls'>

# %%
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.hexbin(x="Day Mins",y="Night Mins",gridsize=20)
# Out:
# <Axes: xlabel='Day Mins', ylabel='Night Mins'>

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
print(df.isnull().sum())
# Out:
# State             0
# Account Length    0
# Area Code         0
# Phone             0
# Int'l Plan        0
# VMail Plan        0
# VMail Message     0
# Day Mins          0
# Day Calls         0
# Day Charge        0
# Eve Mins          0
# Eve Calls         0
# Eve Charge        0
# Night Mins        0
# Night Calls       0
# Night Charge      0
# Intl Mins         0
# Intl Calls        0
# Intl Charge       0
# CustServ Calls    0
# Churn?            0
# dtype: int64

# %%
print("Duplicated values",df.duplicated().sum())
# Out:
# Duplicated values 0

# %%
print("Account Length Statistics:")
print(df["Account Length"].describe())
# Out:
# Account Length Statistics:
# count    3333.000000
# mean      101.064806
# std        39.822106
# min         1.000000
# 25%        74.000000
# 50%       101.000000
# 75%       127.000000
# max       243.000000
# Name: Account Length, dtype: float64

# %%
import seaborn as sns
plt.figure(figsize=(8,6))
sns.boxplot(x=df["Intl Calls"])
plt.title("International Call distribution with outliners")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df["VMail Plan"]=le.fit_transform(df["VMail Plan"])
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  VMail Plan  \
# 0    KS             128        415  382-4657         no           1
# 1    OH             107        415  371-7191         no           1
# 2    NJ             137        415  358-1921         no           0
# 3    OH              84        408  375-9999        yes           0
# 4    OK              75        415  330-6626        yes           0
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0             25     265.1        110       45.07  ...       16.78
# 1             26     161.6        123       27.47  ...       16.62
# 2              0     243.4        114       41.38  ...       10.30
# 3              0     299.4         71       50.90  ...        5.26
# 4              0     166.7        113       28.34  ...       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
df["ToTal Mins"]=df["Day Mins"]+df["Eve Mins"]+df["Night Mins"]
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0             25     265.1        110       45.07  ...       16.78
# 1             26     161.6        123       27.47  ...       16.62
# 2              0     243.4        114       41.38  ...       10.30
# 3              0     299.4         71       50.90  ...        5.26
# 4              0     166.7        113       28.34  ...       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# ...

# %%
account_bins=[0,50,100,150]
account_labels=["Small","Medium","Large"]
df["Account Length"]=pd.cut(df["Account Length"],bins=account_bins,labels=account_labels)
df.head()
# Out:
#   State Account Length  Area Code     Phone Int'l Plan  VMail Plan  \
# 0    KS          Large        415  382-4657         no           1
# 1    OH          Large        415  371-7191         no           1
# 2    NJ          Large        415  358-1921         no           0
# 3    OH         Medium        408  375-9999        yes           0
# 4    OK         Medium        415  330-6626        yes           0
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0             25     265.1        110       45.07  ...       16.78
# 1             26     161.6        123       27.47  ...       16.62
# 2              0     243.4        114       41.38  ...       10.30
# 3              0     299.4         71       50.90  ...        5.26
# 4              0     166.7        113       28.34  ...       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# ...

# %%
vmail_bins=[0,15,30,45,float("inf")]
vmail_labels=["Low","Medium","High","Very High"]
df["VMail Category"]=pd.cut(df["VMail Message"],bins=vmail_bins,labels=vmail_labels)
df.head()
# Out:
#   State Account Length  Area Code     Phone Int'l Plan  VMail Plan  \
# 0    KS          Large        415  382-4657         no           1
# 1    OH          Large        415  371-7191         no           1
# 2    NJ          Large        415  358-1921         no           0
# 3    OH         Medium        408  375-9999        yes           0
# 4    OK         Medium        415  330-6626        yes           0
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Night Mins  \
# 0             25     265.1        110       45.07  ...       244.7
# 1             26     161.6        123       27.47  ...       254.4
# 2              0     243.4        114       41.38  ...       162.6
# 3              0     299.4         71       50.90  ...       196.9
# 4              0     166.7        113       28.34  ...       186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3         2.70
# ...

# %%
columns_to_keep=["Day Calls","Eve Calls","Night Calls"]
churn_data=df[columns_to_keep]
churn_data.head()
# Out:
#    Day Calls  Eve Calls  Night Calls
# 0        110         99           91
# 1        123        103          103
# 2        114        110          104
# 3         71         88           89
# 4        113        122          121

# %%
day_calls_counts=churn_data["Day Calls"].value_counts()

plt.figure(figsize=(8,6))
plt.pie(day_calls_counts,labels=day_calls_counts.index,autopct="%1.1f%%")
plt.axis("equal")
plt.title("Proportion of Day Calls")
plt.show()

# %%
cor_matrix=churn_data.corr()

plt.figure(figsize=(8,6))
sns.heatmap(cor_matrix,annot=True,cmap="coolwarm")
plt.title("Correlation matrix heatmap")
plt.show()
