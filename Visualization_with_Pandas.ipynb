# %%
import pandas as pd
import matplotlib as plt

data_frame=pd.read_csv("sensor_data.csv")
data_frame.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
data_frame.plot()
# Out:
# <Axes: >

# %%
data_frame.plot(kind="scatter",x="Duration",y="Calories")
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
data_frame.plot(x="Duration",y="Pulse")
# Out:
# <Axes: xlabel='Duration'>

# %%
data_frame.plot.scatter(x="Duration",y="Pulse")
# Out:
# <Axes: xlabel='Duration', ylabel='Pulse'>

# %%
data_frame.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_frame.plot.area()
# Out:
# <Axes: >

# %%
data_frame.plot(kind="bar")
#data_frame.plot.bar()
# Out:
# <Axes: >

# %%
data_frame.plot.bar(stacked="True")
# Out:
# <Axes: >

# %%
data_frame.plot.barh()
# Out:
# <Axes: >

# %%
data_frame.plot.box()
# Out:
# <Axes: >

# %%
data_frame.plot.hexbin(x="Maxpulse",y="Calories",gridsize=20)
# Out:
# <Axes: xlabel='Maxpulse', ylabel='Calories'>

# %%
data_frame.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data_frame.plot.pie(y="Duration",autopct="1%.1f%%")
# Out:
# <Axes: ylabel='Duration'>
